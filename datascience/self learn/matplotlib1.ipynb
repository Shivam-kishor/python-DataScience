# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Weather Data Visualization

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y,label='max temp',color='hotpink',linewidth=2,marker="o",markersize=10)
