# %%
#28-sep-2022
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
for i in os.listdir('data'):
    print(i)
# Out:
# amazon_laptops.csv
# amazon_laptops.json
# blood_transfusion.csv
# Canada.xlsx
# cps_85_wages.csv
# laptop_data.csv
# weather.csv

# %%
#get full data row*column
pd.read_excel('data/Canada.xlsx',sheet_name='Canada by Citizenship',skiprows=20,skipfooter=2)
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  1981  1982  1983  \
# 0         Southern Asia  902  Developing regions    16    39    39    47
# ...

# %% [markdown]
# Steps

# %%
pd.read_csv('data/blood_transfusion.csv')
# Out:
#      Recency  Frequency  Monetary  Time        Class
# 0          2         50     12500    98      donated
# 1          0         13      3250    28      donated
# 2          1         16      4000    35      donated
# 3          2         20      5000    45      donated
# 4          1         24      6000    77  not donated
# ..       ...        ...       ...   ...          ...
# 743       23          2       500    38  not donated
# 744       21          2       500    52  not donated
# 745       23          3       750    62  not donated
# 746       39          1       250    39  not donated
# 747       72          1       250    72  not donated
#
# [748 rows x 5 columns]

# %%
pd.read_json('data/amazon_laptops.json')
# Out:
#                                                 title     price  \
# 0   Samsung Galaxy Book2 Intel 12th Gen core i5 39...    69,990
# 1   HP 15s 12th Gen Intel Core i5 8GB RAM/512GB SS...    57,990
# 2   ASUS VivoBook 14 (2021), 14-inch (35.56 cm) HD...    28,990
# 3   Dell Inspiron 3000 Business Laptop, 15.6 HD Di...    70,831
# 4   ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...    25,990
# 5   ASUS ZenBook 14 (2020) Intel Core i5-1135G7 11...    78,989
# 6   Lenovo IdeaPad Slim 3 Intel Celeron N4020 15.6...    27,290
# 7   Lenovo IdeaPad Slim 1 Intel Celeron N4020 11.6...    21,789
# 8   HP 15- AMD Ryzen 3-3250U 15.6 inch(39.6 cm) FH...    38,999
# 9   HP NB 255 G8 Laptop (AMD Ryzen 3-3250U/8GB DDR...    29,385
# 10  HP 14s, 5th Gen AMD Ryzen 3- 8GB RAM/512GB SSD...    38,490
# 11  Redmi Book Pro Intel Core i5 11th Gen H Series...    39,990
# 12  Samsung Galaxy Book2 Pro 360 Intel 12th Gen i7...  1,29,990
# 13  Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 1...    59,490
# ...

# %%
#index_col is used to set the index of the dataframe,if available in the data
pd.read_csv('data/laptop_data.csv',index_col=0)
# Out:
#                                                     NAME      PRICE  \
# INDEX
# 0      MSI Core i9 12th Gen - (32 GB/2 TB SSD/Windows...  ₹3,90,990
# 1      Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core 5600...    ₹59,990
# 2      ASUS Vivobook 15 Core i3 10th Gen - (8 GB/256 ...    ₹27,990
# 3      MSI Modern 14 Ryzen 5 Hexa Core 5500U - (8 GB/...    ₹39,990
# 4      Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...    ₹48,990
# ...                                                  ...        ...
# 523    Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core 5600...    ₹59,990
# 524    ASUS Ryzen 5 Hexa Core - (8 GB/512 GB SSD/Wind...    ₹55,600
# 525    LG Gram Core i5 11th Gen - (8 GB/256 GB SSD/Wi...    ₹76,990
# 526    ASUS ROG Zephyrus G15 (2022) with 90Whr Batter...  ₹2,07,990
# 527    MSI Crosshair 15 Core i7 12th Gen - (16 GB/1 T...  ₹1,16,990
#
#                                                   LINK's
# INDEX
# 0      /msi-core-i9-12th-gen-32-gb-2-tb-ssd-windows-1...
# ...

# %%
pd.read_csv('data/weather.csv')
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
#if a column is a date,you can parse it as a date and time it will  be converted to a daytime object 
pd.read_csv('data/weather.csv',parse_dates=['Date.Full'],dayfirst=True)
# Out:
#        Data.Precipitation  Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00 2016-01-03           1             3       2016
# 1                    0.00 2016-01-03           1             3       2016
# 2                    0.16 2016-01-03           1             3       2016
# 3                    0.00 2016-01-03           1             3       2016
# 4                    0.01 2016-01-03           1             3       2016
# ...                   ...        ...         ...           ...        ...
# 16738                0.08 2017-01-01           1             1       2017
# 16739                0.00 2017-01-01           1             1       2017
# 16740                0.00 2017-01-01           1             1       2017
# 16741                0.06 2017-01-01           1             1       2017
# 16742                0.10 2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
pd.set_option('display.max_columns',None)#setting to enable all colum visible in df

# %% [markdown]
# getting the basics information data
# remove the colm that are"nt need
# renam acoording to ur self
# set the index of the
# rename the index of   dataframe if it is needed
# add a new column to the dataframe
# select the rows of the datafraem
# select the coulmn of the dataframe

# %%
#column info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
# ...

# %%
df.select_dtypes(include=np.number)#viw just numeric data frame

# %%
df.select_dtypes(exclude=np.number)

# %%
df.columns#display all columns name in the data

# %%
df.describe()#nmerical statistics

# %%
df.describe(include='object')#textual stats

# %%
df.head (3)#show the partiular row

# %%
df.tail(4)#from last view

# %%
#show 5 row from head and tail
df

# %%
df.AREA.value_counts()

# %%
df.AreaName.value_counts()

# %%
cols_to_drop=['Type','Coverage','AREA','REG','DEV']
df.drop(columns=cols_to_drop,inplace=True)#it will apply the result to dataframe itself
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Shiva\Documents\python DataScience\datascience\data_analytics1.ipynb Cell 23 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Shiva/Documents/python%20DataScience/datascience/data_analytics1.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> cols_to_drop=['Type','Coverage','AREA','REG','DEV']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Shiva/Documents/python%20DataScience/datascience/data_analytics1.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> df.drop(columns=cols_to_drop,inplace=True)
#
# File c:\Users\Shiva\miniconda3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
# ...

# %%
df.drop(index=[0,2,4,6,8)]#row are remove when index no are given
# Out:
#   Input In [34]
#     df.drop(index=[0,2,4,6,8)]#row are remove when index no are given
#                             ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Shiva\Documents\python DataScience\datascience\data_analytics1.ipynb Cell 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Shiva/Documents/python%20DataScience/datascience/data_analytics1.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> df.columns
#
# NameError: name 'df' is not defined

# %%
df.columns({
    'OdName':'country',
    'AreaName':'continent',


}
df
# Out:
#   Input In [4]
#     df
#     ^
# SyntaxError: invalid syntax

# %%
df.iloc['INDIA']#row wise
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Shiva\Documents\python DataScience\datascience\data_analytics1.ipynb Cell 27 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Shiva/Documents/python%20DataScience/datascience/data_analytics1.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> df.iloc['INDIA']
#
# NameError: name 'df' is not defined

# %%
df.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Shiva\Documents\python DataScience\datascience\data_analytics1.ipynb Cell 28 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Shiva/Documents/python%20DataScience/datascience/data_analytics1.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> df.index
#
# NameError: name 'df' is not defined

# %%
df.plot?
# Out:
# Object `df.plot` not found.

# %%
df.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Shiva\Documents\python DataScience\datascience\data_analytics1.ipynb Cell 30 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Shiva/Documents/python%20DataScience/datascience/data_analytics1.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> df.index
#
# NameError: name 'df' is not defined

# %%
df[]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Shiva\Documents\python DataScience\datascience\data_analytics1.ipynb Cell 31 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Shiva/Documents/python%20DataScience/datascience/data_analytics1.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> df[square]
#
# NameError: name 'df' is not defined
